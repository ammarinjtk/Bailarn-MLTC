# %%
from main import Magpie

magpie = Magpie()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1210: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1299: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# ...

# %%
magpie.train_word2vec('./data/corpus', vec_dim=300)
# Out:
# read text! ./data/corpus/257.txt
# read text! ./data/corpus/65.txt
# read text! ./data/corpus/903.txt
# read text! ./data/corpus/539.txt
# read text! ./data/corpus/28.txt
# read text! ./data/corpus/523.txt
# read text! ./data/corpus/205.txt
# read text! ./data/corpus/815.txt
# read text! ./data/corpus/902.txt
# read text! ./data/corpus/98.txt
# read text! ./data/corpus/516.txt
# read text! ./data/corpus/988.txt
# read text! ./data/corpus/178.txt
# read text! ./data/corpus/236.txt
# read text! ./data/corpus/246.txt
# read text! ./data/corpus/759.txt
# read text! ./data/corpus/448.txt
# read text! ./data/corpus/951.txt
# read text! ./data/corpus/942.txt
# read text! ./data/corpus/657.txt
# read text! ./data/corpus/330.txt
# read text! ./data/corpus/952.txt
# read text! ./data/corpus/821.txt
# read text! ./data/corpus/735.txt
# read text! ./data/corpus/519.txt
# read text! ./data/corpus/957.txt
# read text! ./data/corpus/126.txt
# read text! ./data/corpus/169.txt
# ...

# %%
# Read labels
file = open("./data/corpus.labels", 'r', encoding="utf-8")
labels = file.read().split("\n")
file.close()
# labels = ['Gravitation and Cosmology', 'Experiment-HEP', 'Theory-HEP']

# %%
magpie.train('./data/corpus', labels, test_ratio=0.2, epochs=30)
# Out:
# read text! ./data/corpus/257.txt
# self.text โทรศัพท์Nokialumia0000เค้าเลิกผลิตแล้วรึยัง
# ตามหัวข้อที่ตั้งไว้เลยค่ะแล้วถ้าตอนนี้ยังมีอยู่ราคามันอยู่ที่เท่าไหร่หรอค่ะ
# read text! ./data/corpus/65.txt
# self.text จะซื้อmi0มือสองหรือจะรอmi0ดีครับ
#
# read text! ./data/corpus/903.txt
# self.text อยากรู้ว่ามือถือรุ่นไหนFullHDบ้างคับ
# จะซื้อมือถือใหม่เลยถามก่อนครับ  คือตอนนี้ใช้มือถือรุ่นsamsungnote0n000  อยู่ครับ  มันไม่FullHDคับเลยจะออกใหม่เลยอยากร็ว่ามีรุ่นไหนบ้างที่FullHDแค่นี้คับแล้วiphone0splus  FullHDไหมคับแล้วสามารณเล่มเกมที่มีสเปคสูงๆได้ลื่นไหม
# read text! ./data/corpus/539.txt
# self.text มีแอพที่บอกว่าใครส่องIGเราบ่อยๆด้วยหรอคะ
# ...

# %%
# magpie.batch_train('./data/corpus', labels, epochs=30)

# %%
magpie.predict_from_text('iphone5')
# Out:
# self.text iphone5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3a10576aed7d> in <module>()
# ----> 1 magpie.predict_from_text('iphone5')
#
# ~/Documents/PROJECT/Multi-Label-Text-Classification/main.py in predict_from_text(self, text)
#     185         """
#     186         doc = Document(0, None, text=text)
# --> 187         return self._predict(doc)
#     188
#     189     def _predict(self, doc):
#
# ~/Documents/PROJECT/Multi-Label-Text-Classification/main.py in _predict(self, doc)
#     198             _, sample_length, embedding_size = self.keras_model.input_shape
#     199
# --> 200         words = doc.get_all_words()[:sample_length]
#     201         x_matrix = np.zeros((1, sample_length, embedding_size))
#     202
#
# ~/Documents/PROJECT/Multi-Label-Text-Classification/base/document.py in get_all_words(self)
# ...

# %%
magpie.tokenizer_model

# %% [markdown]
# # Playground
# - is Tokenizer work ?

# %%
from base import document
doc = document.Document(0, "./data/corpus/0.txt", tokenizer_model=magpie.tokenizer_model)

# %%
doc.get_all_words()
# Out:
# ['อัพเดต',
#  'ทาง',
#  'shopee',
#  'ติดต่อ',
#  'มา',
#  'ครับ',
#  'ส่วน',
#  'ระบบ',
#  'ใคร',
#  'จะ',
#  'ถูก',
#  'ผิด',
#  'ผม',
#  'ไม่',
#  'ทราบ',
#  'ได้',
#  'สิ่ง',
#  'ที่',
#  'ควร',
#  'ทำ',
#  'คือ',
#  'ปรับปรุง',
#  'แก้ไข',
#  'ไม่ว่า',
#  'จะ',
#  'ทาง',
#  'ร้าน',
#  'หรือ',
#  'ทาง',
#  'Shopee',
#  'โดย',
#  'ทาง',
#  'shopee',
#  'ออก',
#  'โค้ด',
#  'ส่วน',
#  'ลด',
#  'ให้',
#  'ใหม่',
#  'และ',
#  'ผม',
#  'ได้',
#  'เครื่อง',
#  'เรียบร้อย',
#  'ขอบคุณ',
#  'การ',
#  'แก้ไข',
#  'ของ',
#  'shopee',
#  'ส่วน',
#  'ร้าน',
#  'ก็',
#  'อยาก',
#  'ให้',
#  'ปรับปรุง',
#  'เพราะ',
#  'ผม',
#  'ยังคง',
#  'กังขา',
#  'ทุก',
#  'อย่าง',
#  'มัน',
#  'ดู',
#  'แปลก',
#  'ๆ',
#  'แจ้ง',
#  'เตือน',
#  'ดีล',
#  'ของ',
#  'ร้าน',
#  'NASAmbk',
#  'ใน',
#  'shopee',
#  'ตาม',
#  'ที่',
#  'ผม',
#  'คาด',
#  'การณ์',
#  'ไว้',
#  'ยื้อ',
#  'การ',
#  'ส่ง',
#  'ของ',
#  'จน',
#  'หมด',
#  'เวลา',
#  'ระบบ',
#  'shopee',
#  'จะ',
#  'ยกเลิก',
#  'ออเดอร์',
# ...
